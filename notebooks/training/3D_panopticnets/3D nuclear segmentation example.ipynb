# %% [markdown]
# This notebook is part of the `deepcell-tf` documentation: https://deepcell.readthedocs.io/.

# %% [markdown]
# # Training a segmentation model
#
# `deepcell-tf` leverages [Jupyter Notebooks](https://jupyter.org) in order to train models. Example notebooks are available for most model architectures in the [notebooks folder](https://github.com/vanvalenlab/deepcell-tf/tree/master/notebooks). Most notebooks are structured similarly to this example and thus this notebook serves as a core reference for the deepcell approach to model training.

# %%
import os
import errno
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from skimage.segmentation import relabel_sequential
from skimage.transform import rescale, resize
from IPython.display import HTML

import deepcell
from deepcell.utils.plot_utils import get_js_video
from deepcell.utils.utils_3D import get_3D_cell_statistics, load_mousebrain_data#, tile_predict_watershed
from deepcell_toolbox.deep_watershed import deep_watershed_3D
from deepcell_toolbox.utils import tile_image_3D, untile_image_3D

# %% [markdown]
# ## Load data

# %%
# Ask Geneva for help with this 

filepath = '/images/data/cells/MouseBrain/3D_annotations/attempt2'
set_nums = 4
test_size = 0.2
seed = 7

X_train, X_test, y_train, y_test = load_mousebrain_data(filepath, set_nums, test_size=test_size, seed=seed)
print('X_train.shape: {}\ty_train.shape: {}'.format(X_train.shape, y_train.shape))
print('X_test.shape: {}\ty_test.shape: {}'.format(X_test.shape, y_test.shape))
# Out:
# X_train.shape: (11, 47, 512, 512, 1)	y_train.shape: (11, 47, 512, 512, 1)
# X_test.shape: (3, 47, 512, 512, 1)	y_test.shape: (3, 47, 512, 512, 1)

# %% [markdown]
# ## Set up filepath constants

# %%
# Ask Dylan about setting up Docker and what to do about file paths here (can also ask Geneva)

filename = '--.npz'

DATA_DIR = os.path.expanduser(os.path.join(filepath))

# DATA_FILE should be a npz file, preferably from `make_training_data`
DATA_FILE = os.path.join(DATA_DIR, filename)

# If the data file is in a subdirectory, mirror it in MODEL_DIR and LOG_DIR
PREFIX = os.path.relpath(os.path.dirname(DATA_FILE), DATA_DIR)

# save models on madrox
ROOT_DIR = '/deepcell_data'
MODEL_DIR = os.path.abspath(os.path.join(ROOT_DIR, 'models', PREFIX))
LOG_DIR = os.path.abspath(os.path.join(ROOT_DIR, 'logs', PREFIX))

# create directories if they do not exist
for d in (MODEL_DIR, LOG_DIR):
    try:
        os.makedirs(d)
    except OSError as exc:  # Guard against race condition
        if exc.errno != errno.EEXIST:
            raise

# %% [markdown]
# ## View cell statistics

# %%
stats = get_3D_cell_statistics(np.concatenate((y_train, y_test), axis=0))

print('Cell dimensions: mean x is {}, mean y is {}, and mean z is {}'.format(
    stats['x_mean'], stats['y_mean'], stats['z_mean']))
# Out:
# Cell dimensions: mean x is 36.07, mean y is 38.4, and mean z is 15.95

# %% [markdown]
# ## Prepare data
#
# ### Set up input and augmentation parameters
# **model_name**: Incorporated into any files generated during the training process.
#
# **frame_shape**: Defines the x & y dimensions of the model input. They must be equivalent powers of 2. A good starting point is to set this as the smallest power of 2 that is greater than the mean x & y dimensions.
#
# **frames_per_batch**: Defines the z dimensions of the model input. Can be any integer ranging from 1 to the max height of the data. A good starting point is to set this as just greater than the mean cell height.
#
# **aug_3d**: Whether or not to perform 3d spatial data augmentation. With just this flag on, the only augmentation performed in 3d is flipping. It is recommended to leave this on for all 3d data.
#
# **rotation_3d**: Choose the range in degrees for rotation in 3d (rotating the xz and yz planes in addition to xy). Highly recommended to start out leaving this at 0. Can experiment with increasing this - if so, I would recommend staying within the range of 1-15. Larger rotation ranges result in significant clipping out of data. It should also be noted that using 3d_rotation *significantly* slows down training, as each batch is individually scaled down before being returned.
#
# **sampling**: The pixelwise sampling ratio for the data - sampling along the z-axis tends to be of a lower resolution compared with x & y. This will be different for most datasets, and MUST be entered. If this is not known for your dataset, a rough sampling approximation (assuming x and y are scaled the same, which they typically are) can be calculated using the mean cell dimensions as follows:
# ((x+y)/2)/z = z_scale -----------> example: ((36.07+38.4)/2)/15.95 = 2.33, actual scale = 0.5/0.217 = 2.30
# sampling = [z_scale, 1, 1]
#
# **by_frame_inner**: If False, transform inner-distance (used to identify cell centroids) in 3D. Must ALWAYS be False for 3d data.
#
# **by_frame_outer**: If False, transform outer-distance (used to define cell area) in 3D. Generally should be 3D, but can sometimes be beneficial to set this to True (performing this transform in 2D).
#
# **temporal_mode**: Method by which temporal features (in this case the z-stack along the z-axis) are merged in model construction. One of None, 'conv', 'gru', or 'lstm'. Lstm mode seems to be broken, and the others do not seem to provide significant benefit. **Not sure if working as intended - would recommend taking another look before using.**
#
# **z_axis_convolutions**: Whether or not to perform convolutions along the z-axis. Should theoretically be equivalent to temporal_mode==conv. Would recommend starting with this on (True).
#
# **fill_mode**: When performing rotation, part of the image will be clipped out, leaving an empty space in its place - fill_mode determines what will replace that empty space. One of 'constant', 'nearest', 'reflect', and 'wrap'. Best options seem to be 'constant' and 'nearest', as both 'reflect' and 'wrap' have the potential to create fused "cells" that have 2 centroids.
#
# **min_objects**: Images with less than this number of objects are thrown out. This actually does not work with the cropping implementation (as the "given input image" is the entire image, not the crop - so typically nothing will get thrown out). One useful improvement would be development of a cropping data generator for 3d (see the 2d cropping datagen), so that minimum objects could be applied to individual crops.
#
# **batch_size**: The batch size determines the number of samples that are processed before the model is updated. The value must be greater than one and less than or equal to the number of samples in the training dataset. Make this as large as possible, but memory will be an issue - somewhere between 1 and 4 is likely realistic.

# %%
# Ask Cole for help/advice on what would be best here

model_name = 'mousebrain3D_27x64_random_cropping_3daug_rotate_nearest' # Change with each new model ***

# 47 x 512 x 512 x 1

frame_shape = (64, 64, 1)           # Change depending on cell dimensions and what fits in memory ***
frames_per_batch = 28               # ^ same as above ***

aug_3d = True                       # Leave at True
rotation_3d = 0                     # Leave at 0 for now 
sampling = [0.5, 0.217, 0.217]      # Ask Geneva to ask source of data for sampling ***
z_scale = sampling[0] / sampling[1]

if aug_3d and rotation_3d > 0:
    sampling = [sampling[1], sampling[1], sampling[1]]

by_frame_inner = False        # Always leave as False
by_frame_outer = False        # Default to False, can try changing to True *
temporal_mode = None          # Leave as None
z_axis_convolutions = True    # Default to True, can try changing to False *

fill_mode = 'nearest'         # Default to nearest, try changing to constant *
cval = 0                      # fill value to use with fill_mode = constant. Leave this at 0. 
min_objects = 1               # Doesn't matter to you - doesn't work
batch_size = 3                # Bigger is better, too big won't fit in memory ***

# %%
from deepcell import image_generators
from deepcell.utils import train_utils

transforms = ['inner-distance', 'outer-distance', 'fgbg', 'pixelwise']
transforms_kwargs = {'outer-distance': {'erosion_width': 0, 'by_frame' : by_frame_outer, 'sampling': sampling},
                     'inner-distance': {'by_frame' : by_frame_inner, 'sampling': sampling},
                     'pixelwise': {'separate_edge_classes' : False, 'dilation_radius' : 1}}

# use augmentation for training but not validation
datagen = image_generators.Semantic3DGenerator(
    rotation_range=180,
    shear_range=0,
    zoom_range=(0.75, 1.25),
    fill_mode=fill_mode,
    cval=cval,
    horizontal_flip=True,
    vertical_flip=True)

datagen_val = image_generators.Semantic3DGenerator(
    rotation_range=0,
    shear_range=0,
    zoom_range=0,
    fill_mode=fill_mode,
    cval=cval,
    horizontal_flip=0,
    vertical_flip=0)

train_data = datagen.flow(
    {'X': X_train, 'y': y_train},
    seed=seed,
    transforms=transforms,
    frames_per_batch=frames_per_batch,
    frame_shape=frame_shape,
    transforms_kwargs=transforms_kwargs,
    aug_3d=aug_3d,
    rotation_3d=rotation_3d,
    z_scale=z_scale,
    min_objects=min_objects,
    batch_size=batch_size)

val_data = datagen_val.flow(
    {'X': X_test, 'y': y_test},
    seed=seed,
    frames_per_batch=frames_per_batch,
    frame_shape=frame_shape,
    transforms=transforms,
    transforms_kwargs=transforms_kwargs,
    aug_3d=False,
    rotation_3d=0,
    min_objects=min_objects,
    batch_size=batch_size)

# %%
from matplotlib import pyplot as plt

inputs, outputs = train_data.next()

img = inputs[0]
inner_distance = outputs[0]
outer_distance = outputs[1]
fgbg = outputs[2]
pixelwise = outputs[3]

fig, axes = plt.subplots(1, 5, figsize=(15, 15))

slice=12

axes[0].imshow(img[slice, ..., 0], cmap='jet')
axes[0].set_title('Source Image')

axes[1].imshow(inner_distance[0, slice, ..., 0])
axes[1].set_title('Inner Distance')

axes[2].imshow(outer_distance[0, slice, ..., 0])
axes[2].set_title('Outer Distance')

axes[3].imshow(fgbg[0, slice, ..., 1])
axes[3].set_title('Foreground/Background')

axes[4].imshow(pixelwise[0, slice, ..., 0])
axes[4].set_title('Pixelwise - edge')

plt.show()

# %%
HTML(get_js_video(inputs, batch=0, channel=0, interval=100, cmap='jet'))
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img356c9209d93f4c6faad999cbfcb973a8">
#   <div class="anim-controls">
#     <input id="_anim_slider356c9209d93f4c6faad999cbfcb973a8" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim356c9209d93f4c6faad999cbfcb973a8.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" onclick="anim356c9209d93f4c6faad999cbfcb973a8.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" onclick="anim356c9209d93f4c6faad999cbfcb973a8.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" onclick="anim356c9209d93f4c6faad999cbfcb973a8.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" onclick="anim356c9209d93f4c6faad999cbfcb973a8.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" onclick="anim356c9209d93f4c6faad999cbfcb973a8.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" onclick="anim356c9209d93f4c6faad999cbfcb973a8.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" onclick="anim356c9209d93f4c6faad999cbfcb973a8.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" onclick="anim356c9209d93f4c6faad999cbfcb973a8.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" onclick="anim356c9209d93f4c6faad999cbfcb973a8.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" action="#n" name="_anim_loop_select356c9209d93f4c6faad999cbfcb973a8"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_356c9209d93f4c6faad999cbfcb973a8"
#              >
#       <label for="_anim_radio1_356c9209d93f4c6faad999cbfcb973a8">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_356c9209d93f4c6faad999cbfcb973a8"
#              checked>
#       <label for="_anim_radio2_356c9209d93f4c6faad999cbfcb973a8">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_356c9209d93f4c6faad999cbfcb973a8"
#              >
#       <label for="_anim_radio3_356c9209d93f4c6faad999cbfcb973a8">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img356c9209d93f4c6faad999cbfcb973a8";
#     var slider_id = "_anim_slider356c9209d93f4c6faad999cbfcb973a8";
#     var loop_select_id = "_anim_loop_select356c9209d93f4c6faad999cbfcb973a8";
#     var frames = new Array(28);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjMuMCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy86wFpkAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAAhs0lEQVR4nO3db6xkxXnn8d/DDMPYDHCBgQEz2AOGGCEnDM7If2I2i806Yh3L\
# 1koWipNdsRESb7wrR5so4LxZJ1pL9ps41mplaWQ74YVjmzjxgryWYzIxykbZxR4vJDb/wpgMYTAz\
# wxCuDYb5y7Mv+tzu6vKtmurj031O3fv9SKNbp+t0neruc2/Near6OebuAgCgNmf03QEAANpgAAMA\
# VIkBDABQJQYwAECVGMAAAFViAAMAVI

# %%
HTML(get_js_video(outer_distance, batch=0, channel=0, interval=100, cmap='jet'))
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img321eb81392154e9cb13fe2e4da67c0df">
#   <div class="anim-controls">
#     <input id="_anim_slider321eb81392154e9cb13fe2e4da67c0df" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim321eb81392154e9cb13fe2e4da67c0df.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" onclick="anim321eb81392154e9cb13fe2e4da67c0df.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" onclick="anim321eb81392154e9cb13fe2e4da67c0df.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" onclick="anim321eb81392154e9cb13fe2e4da67c0df.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" onclick="anim321eb81392154e9cb13fe2e4da67c0df.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" onclick="anim321eb81392154e9cb13fe2e4da67c0df.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" onclick="anim321eb81392154e9cb13fe2e4da67c0df.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" onclick="anim321eb81392154e9cb13fe2e4da67c0df.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" onclick="anim321eb81392154e9cb13fe2e4da67c0df.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" onclick="anim321eb81392154e9cb13fe2e4da67c0df.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" action="#n" name="_anim_loop_select321eb81392154e9cb13fe2e4da67c0df"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_321eb81392154e9cb13fe2e4da67c0df"
#              >
#       <label for="_anim_radio1_321eb81392154e9cb13fe2e4da67c0df">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_321eb81392154e9cb13fe2e4da67c0df"
#              checked>
#       <label for="_anim_radio2_321eb81392154e9cb13fe2e4da67c0df">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_321eb81392154e9cb13fe2e4da67c0df"
#              >
#       <label for="_anim_radio3_321eb81392154e9cb13fe2e4da67c0df">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img321eb81392154e9cb13fe2e4da67c0df";
#     var slider_id = "_anim_slider321eb81392154e9cb13fe2e4da67c0df";
#     var loop_select_id = "_anim_loop_select321eb81392154e9cb13fe2e4da67c0df";
#     var frames = new Array(28);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjMuMCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy86wFpkAAAACXBIWXMAAAsT\
# AAALEwEAmpwYAAAl1ElEQVR4nO3db2xc13nn8d8jkiJFUdJYUkzJlh0qtjZu0DZ2IOQPEnTdeFN4\
# u0GzL4KgaXfhLQz4TXaRYls0Tt9s290AyZumebEIICRpDWzbxJs2ayMo0hreBNsFFm6U2m0SO65d\
# R46lWJJFeWTREimRPvtiLjnPech7PZYp3jnU9wMYPHfOmTuHM6SO7/McPtdSSgIAoDRb2p4AAABX\
# ggUMAFAkFjAAQJFYwAAARWIBAwAUiQ

# %% [markdown]
# ## Create the PanopticNet Model
#
# Here we instantiate a `PanopticNet` model from `deepcell.model_zoo` using 3 semantic heads:
# inner distance (1 class),
# outer distance (1 class),
# foreground/background distance (2 classes)

# %%
from deepcell.model_zoo.panopticnet import PanopticNet

if frame_shape:
    input_shape = frame_shape
else:
    input_shape = X_train.shape[2:]
    
model = PanopticNet(
    backbone='resnet50',
    input_shape=input_shape,
    frames_per_batch=frames_per_batch, 
    norm_method='std',
    num_semantic_heads=4,
    temporal_mode=temporal_mode,
    num_semantic_classes=[1, 1, 2, 3], # inner distance, outer distance, fgbg
    location=True,  # should always be true
    include_top=True,
    z_axis_convolutions=z_axis_convolutions)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0804 04:38:48.074233 140642852083520 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 6s 0us/step
# Using convolutions across the z-axis
# Using convolutions across the z-axis
# Using convolutions across the z-axis

# %% [markdown]
# ## Prepare for training
#
# ### Set up training parameters.
#
# **n_epoch**: The number of complete passes through the training dataset.
#
# **optimizer**: The TensorFlow module [tf.keras.optimizers](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers) offers optimizers with a variety of algorithm implementations. DeepCell typically uses the Adam or the SGD optimizers.
#
# **lr**: The learning rate determines the speed at which the model learns. Specifically it controls the relative size of the updates to model values after each batch.
#
# **lr_sched**: A learning rate scheduler allows the learning rate to adapt over the course of model training. Typically a larger learning rate is preferred during the start of the training process, while a small learning rate allows for fine-tuning during the end of training.

# %%
from tensorflow.keras.optimizers import SGD, Adam
from deepcell.utils.train_utils import rate_scheduler

n_epoch = 20
test_size = .20
optimizer = Adam(lr=1e-5, clipnorm=0.001)
lr_sched = rate_scheduler(lr=1e-5, decay=0.99)
model_path = os.path.join(MODEL_DIR, '{}.h5'.format(model_name))
loss_path = os.path.join(MODEL_DIR, '{}.npz'.format(model_name))

# %% [markdown]
# ### Create a loss function for each semantic head
#
# Each semantic head is trained with it's own loss function. Mean Square Error is used for regression-based heads, whereas `weighted_categorical_crossentropy` is used for classification heads.
#
# The losses are saved as a dictionary and passed to `model.compile`.

# %%
# Create a dictionary of losses for each semantic head
from tensorflow.python.keras.losses import MSE
from deepcell import losses


def semantic_loss(n_classes):
    def _semantic_loss(y_pred, y_true):
        if n_classes > 1:
            return 0.01 * losses.weighted_categorical_crossentropy(
                y_pred, y_true, n_classes=n_classes)
        return MSE(y_pred, y_true)
    return _semantic_loss


loss = {}

# Give losses for all of the semantic heads
for layer in model.layers:
    if layer.name.startswith('semantic_'):
        n_classes = layer.output_shape[-1]
        loss[layer.name] = semantic_loss(n_classes)

# %%
model.compile(loss=loss, optimizer=optimizer)

# %% [markdown]
# ## Train the model
#
# Call `fit_generator` on the compiled model, along with a default set of callbacks.

# %%
# Compensate for cropping by increasing the number of steps per epoch proportionally
cropping_factor = round((X_train.shape[1] / frames_per_batch) * 
                        (X_train.shape[2] / frame_shape[0]) * 
                        (X_train.shape[3] / frame_shape[1]))

print('Cropping factor is {}'.format(cropping_factor))
# Out:
# Cropping factor is 107

# %%
from deepcell.utils.train_utils import get_callbacks
from deepcell.utils.train_utils import count_gpus

num_gpus = count_gpus()
print('Training on', num_gpus, 'GPUs.')

train_callbacks = get_callbacks(
    model_path,
    lr_sched=lr_sched,
    tensorboard_log_dir=LOG_DIR,
    save_weights_only=num_gpus >= 2,
    monitor='val_loss',
    verbose=1)

loss_history = model.fit_generator(
    train_data,
    steps_per_epoch=cropping_factor * train_data.y.shape[0] // batch_size,
    epochs=n_epoch,
    validation_data=val_data,
    validation_steps=cropping_factor * val_data.y.shape[0] // batch_size,
    callbacks=train_callbacks)
# Out:
# Training on 1 GPUs.
# Epoch 1/50
# W0804 04:39:46.421760 140642852083520 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 391/392 [============================>.] - ETA: 2s - loss: 0.0460 - semantic_0_loss: 0.0166 - semantic_1_loss: 0.0197 - semantic_2_loss: 0.0030 - semantic_3_loss: 0.0067
# Epoch 00001: val_loss improved from inf to 0.02666, saving model to /deepcell_data/models/mousebrain3D_27x64_random_cropping_3daug_norotatev2_test.h5
# 392/392 [==============================] - 919s 2s/step - loss: 0.0459 - semantic_0_loss: 0.0166 - semantic_1_loss: 0.0197 - semantic_2_loss: 0.0030 - semantic_3_loss: 0.0067 - val_loss: 0.0267 - val_semantic_0_loss: 0.0118 - val_semantic_1_loss: 0.0065 - val_semantic_2_loss: 0.0020 - val_semantic_3_loss: 0.0063
# Epoch 2/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0122 - semantic_0_loss: 0.0041 - semantic_1_loss: 0.0024 - semantic_2_loss: 0.0012 - semantic_3_loss: 0.0045
# Epoch 00002: val_loss improved from 0.02666 to 0.02079, saving model to /deepcell_data/models/mousebrain3D_27x64_random_cropping_3daug_norotatev2_test.h5
# 392/392 [==============================] - 852s 2s/step - loss: 0.0123 - semantic_0_loss: 0.0041 - semantic_1_loss: 0.0024 - semantic_2_loss: 0.0012 - semantic_3_loss: 0.0045 - val_loss: 0.0208 - val_semantic_0_loss: 0.0095 - val_semantic_1_loss: 0.0044 - val_semantic_2_loss: 0.0016 - val_semantic_3_loss: 0.0053
# Epoch 3/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0108 - semantic_0_loss: 0.0037 - semantic_1_loss: 0.0021 - semantic_2_loss: 9.8985e-04 - semantic_3_loss: 0.0040
# Epoch 00003: val_loss improved from 0.02079 to 0.01783, saving model to /deepcell_data/models/mousebrain3D_27x64_random_cropping_3daug_norotatev2_test.h5
# 392/392 [==============================] - 847s 2s/step - loss: 0.0108 - semantic_0_loss: 0.0037 - semantic_1_loss: 0.0021 - semantic_2_loss: 9.8926e-04 - semantic_3_loss: 0.0040 - val_loss: 0.0178 - val_semantic_0_loss: 0.0080 - val_semantic_1_loss: 0.0037 - val_semantic_2_loss: 0.0012 - val_semantic_3_loss: 0.0049
# Epoch 4/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0096 - semantic_0_loss: 0.0032 - semantic_1_loss: 0.0018 - semantic_2_loss: 8.7999e-04 - semantic_3_loss: 0.0037
# Epoch 00004: val_loss improved from 0.01783 to 0.01772, saving model to /deepcell_data/models/mousebrain3D_27x64_random_cropping_3daug_norotatev2_test.h5
# 392/392 [==============================] - 846s 2s/step - loss: 0.0096 - semantic_0_loss: 0.0032 - semantic_1_loss: 0.0018 - semantic_2_loss: 8.7914e-04 - semantic_3_loss: 0.0037 - val_loss: 0.0177 - val_semantic_0_loss: 0.0080 - val_semantic_1_loss: 0.0037 - val_semantic_2_loss: 0.0013 - val_semantic_3_loss: 0.0048
# Epoch 5/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0094 - semantic_0_loss: 0.0032 - semantic_1_loss: 0.0017 - semantic_2_loss: 8.5900e-04 - semantic_3_loss: 0.0036
# Epoch 00005: val_loss improved from 0.01772 to 0.01622, saving model to /deepcell_data/models/mousebrain3D_27x64_random_cropping_3daug_norotatev2_test.h5
# 392/392 [==============================] - 853s 2s/step - loss: 0.0094 - semantic_0_loss: 0.0032 - semantic_1_loss: 0.0017 - semantic_2_loss: 8.5794e-04 - semantic_3_loss: 0.0036 - val_loss: 0.0162 - val_semantic_0_loss: 0.0074 - val_semantic_1_loss: 0.0032 - val_semantic_2_loss: 0.0011 - val_semantic_3_loss: 0.0046
# Epoch 6/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0092 - semantic_0_loss: 0.0031 - semantic_1_loss: 0.0017 - semantic_2_loss: 8.4324e-04 - semantic_3_loss: 0.0035
# Epoch 00006: val_loss did not improve from 0.01622
# 392/392 [==============================] - 834s 2s/step - loss: 0.0092 - semantic_0_loss: 0.0031 - semantic_1_loss: 0.0017 - semantic_2_loss: 8.4386e-04 - semantic_3_loss: 0.0035 - val_loss: 0.0168 - val_semantic_0_loss: 0.0076 - val_semantic_1_loss: 0.0036 - val_semantic_2_loss: 0.0012 - val_semantic_3_loss: 0.0044
# Epoch 7/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0084 - semantic_0_loss: 0.0028 - semantic_1_loss: 0.0015 - semantic_2_loss: 7.3133e-04 - semantic_3_loss: 0.0034
# Epoch 00007: val_loss improved from 0.01622 to 0.01374, saving model to /deepcell_data/models/mousebrain3D_27x64_random_cropping_3daug_norotatev2_test.h5
# 392/392 [==============================] - 852s 2s/step - loss: 0.0084 - semantic_0_loss: 0.0028 - semantic_1_loss: 0.0015 - semantic_2_loss: 7.3130e-04 - semantic_3_loss: 0.0034 - val_loss: 0.0137 - val_semantic_0_loss: 0.0058 - val_semantic_1_loss: 0.0026 - val_semantic_2_loss: 0.0011 - val_semantic_3_loss: 0.0043
# Epoch 8/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0085 - semantic_0_loss: 0.0029 - semantic_1_loss: 0.0015 - semantic_2_loss: 7.7448e-04 - semantic_3_loss: 0.0033
# Epoch 00008: val_loss did not improve from 0.01374
# 392/392 [==============================] - 839s 2s/step - loss: 0.0085 - semantic_0_loss: 0.0029 - semantic_1_loss: 0.0015 - semantic_2_loss: 7.7446e-04 - semantic_3_loss: 0.0033 - val_loss: 0.0147 - val_semantic_0_loss: 0.0065 - val_semantic_1_loss: 0.0030 - val_semantic_2_loss: 0.0010 - val_semantic_3_loss: 0.0041
# Epoch 9/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0084 - semantic_0_loss: 0.0028 - semantic_1_loss: 0.0015 - semantic_2_loss: 7.2150e-04 - semantic_3_loss: 0.0033
# Epoch 00009: val_loss did not improve from 0.01374
# 392/392 [==============================] - 833s 2s/step - loss: 0.0084 - semantic_0_loss: 0.0028 - semantic_1_loss: 0.0015 - semantic_2_loss: 7.2094e-04 - semantic_3_loss: 0.0033 - val_loss: 0.0144 - val_semantic_0_loss: 0.0064 - val_semantic_1_loss: 0.0029 - val_semantic_2_loss: 9.9938e-04 - val_semantic_3_loss: 0.0042
# Epoch 10/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0080 - semantic_0_loss: 0.0028 - semantic_1_loss: 0.0014 - semantic_2_loss: 6.9635e-04 - semantic_3_loss: 0.0032
# Epoch 00010: val_loss did not improve from 0.01374
# 392/392 [==============================] - 834s 2s/step - loss: 0.0080 - semantic_0_loss: 0.0028 - semantic_1_loss: 0.0014 - semantic_2_loss: 6.9714e-04 - semantic_3_loss: 0.0032 - val_loss: 0.0148 - val_semantic_0_loss: 0.0065 - val_semantic_1_loss: 0.0028 - val_semantic_2_loss: 0.0011 - val_semantic_3_loss: 0.0044
# Epoch 11/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0082 - semantic_0_loss: 0.0029 - semantic_1_loss: 0.0014 - semantic_2_loss: 6.9403e-04 - semantic_3_loss: 0.0032
# Epoch 00011: val_loss improved from 0.01374 to 0.01348, saving model to /deepcell_data/models/mousebrain3D_27x64_random_cropping_3daug_norotatev2_test.h5
# 392/392 [==============================] - 850s 2s/step - loss: 0.0082 - semantic_0_loss: 0.0029 - semantic_1_loss: 0.0014 - semantic_2_loss: 6.9329e-04 - semantic_3_loss: 0.0032 - val_loss: 0.0135 - val_semantic_0_loss: 0.0059 - val_semantic_1_loss: 0.0027 - val_semantic_2_loss: 8.7468e-04 - val_semantic_3_loss: 0.0039
# Epoch 12/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0078 - semantic_0_loss: 0.0027 - semantic_1_loss: 0.0013 - semantic_2_loss: 6.8135e-04 - semantic_3_loss: 0.0031
# Epoch 00012: val_loss did not improve from 0.01348
# 392/392 [==============================] - 831s 2s/step - loss: 0.0078 - semantic_0_loss: 0.0027 - semantic_1_loss: 0.0013 - semantic_2_loss: 6.8093e-04 - semantic_3_loss: 0.0031 - val_loss: 0.0143 - val_semantic_0_loss: 0.0067 - val_semantic_1_loss: 0.0029 - val_semantic_2_loss: 8.5103e-04 - val_semantic_3_loss: 0.0039
# Epoch 13/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0075 - semantic_0_loss: 0.0025 - semantic_1_loss: 0.0013 - semantic_2_loss: 6.4370e-04 - semantic_3_loss: 0.0031
# Epoch 00013: val_loss did not improve from 0.01348
# 392/392 [==============================] - 834s 2s/step - loss: 0.0075 - semantic_0_loss: 0.0025 - semantic_1_loss: 0.0013 - semantic_2_loss: 6.4342e-04 - semantic_3_loss: 0.0031 - val_loss: 0.0152 - val_semantic_0_loss: 0.0067 - val_semantic_1_loss: 0.0031 - val_semantic_2_loss: 9.6927e-04 - val_semantic_3_loss: 0.0044
# Epoch 14/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0074 - semantic_0_loss: 0.0025 - semantic_1_loss: 0.0012 - semantic_2_loss: 6.4139e-04 - semantic_3_loss: 0.0031
# Epoch 00014: val_loss did not improve from 0.01348
# 392/392 [==============================] - 832s 2s/step - loss: 0.0074 - semantic_0_loss: 0.0025 - semantic_1_loss: 0.0012 - semantic_2_loss: 6.4192e-04 - semantic_3_loss: 0.0031 - val_loss: 0.0136 - val_semantic_0_loss: 0.0061 - val_semantic_1_loss: 0.0026 - val_semantic_2_loss: 9.2896e-04 - val_semantic_3_loss: 0.0039
# Epoch 15/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0075 - semantic_0_loss: 0.0025 - semantic_1_loss: 0.0013 - semantic_2_loss: 6.4377e-04 - semantic_3_loss: 0.0031
# Epoch 00015: val_loss did not improve from 0.01348
# 392/392 [==============================] - 833s 2s/step - loss: 0.0075 - semantic_0_loss: 0.0025 - semantic_1_loss: 0.0013 - semantic_2_loss: 6.4305e-04 - semantic_3_loss: 0.0031 - val_loss: 0.0136 - val_semantic_0_loss: 0.0062 - val_semantic_1_loss: 0.0028 - val_semantic_2_loss: 8.7590e-04 - val_semantic_3_loss: 0.0037
# Epoch 16/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0073 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0012 - semantic_2_loss: 6.1918e-04 - semantic_3_loss: 0.0030
# Epoch 00016: val_loss improved from 0.01348 to 0.01297, saving model to /deepcell_data/models/mousebrain3D_27x64_random_cropping_3daug_norotatev2_test.h5
# 392/392 [==============================] - 845s 2s/step - loss: 0.0073 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0012 - semantic_2_loss: 6.2009e-04 - semantic_3_loss: 0.0030 - val_loss: 0.0130 - val_semantic_0_loss: 0.0059 - val_semantic_1_loss: 0.0026 - val_semantic_2_loss: 8.3019e-04 - val_semantic_3_loss: 0.0037
# Epoch 17/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0075 - semantic_0_loss: 0.0025 - semantic_1_loss: 0.0013 - semantic_2_loss: 6.3597e-04 - semantic_3_loss: 0.0030
# Epoch 00017: val_loss did not improve from 0.01297
# 392/392 [==============================] - 833s 2s/step - loss: 0.0075 - semantic_0_loss: 0.0025 - semantic_1_loss: 0.0013 - semantic_2_loss: 6.3581e-04 - semantic_3_loss: 0.0030 - val_loss: 0.0139 - val_semantic_0_loss: 0.0066 - val_semantic_1_loss: 0.0026 - val_semantic_2_loss: 9.2024e-04 - val_semantic_3_loss: 0.0038
# Epoch 18/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0071 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0011 - semantic_2_loss: 6.0695e-04 - semantic_3_loss: 0.0030
# Epoch 00018: val_loss did not improve from 0.01297
# 392/392 [==============================] - 835s 2s/step - loss: 0.0071 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0011 - semantic_2_loss: 6.0571e-04 - semantic_3_loss: 0.0030 - val_loss: 0.0132 - val_semantic_0_loss: 0.0060 - val_semantic_1_loss: 0.0026 - val_semantic_2_loss: 8.5340e-04 - val_semantic_3_loss: 0.0037
# Epoch 19/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0071 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0012 - semantic_2_loss: 5.9177e-04 - semantic_3_loss: 0.0029
# Epoch 00019: val_loss did not improve from 0.01297
# 392/392 [==============================] - 831s 2s/step - loss: 0.0071 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0012 - semantic_2_loss: 5.9226e-04 - semantic_3_loss: 0.0029 - val_loss: 0.0135 - val_semantic_0_loss: 0.0063 - val_semantic_1_loss: 0.0026 - val_semantic_2_loss: 8.7712e-04 - val_semantic_3_loss: 0.0038
# Epoch 20/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0070 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0011 - semantic_2_loss: 5.9689e-04 - semantic_3_loss: 0.0029
# Epoch 00020: val_loss improved from 0.01297 to 0.01276, saving model to /deepcell_data/models/mousebrain3D_27x64_random_cropping_3daug_norotatev2_test.h5
# 392/392 [==============================] - 849s 2s/step - loss: 0.0070 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0011 - semantic_2_loss: 5.9706e-04 - semantic_3_loss: 0.0029 - val_loss: 0.0128 - val_semantic_0_loss: 0.0057 - val_semantic_1_loss: 0.0027 - val_semantic_2_loss: 7.9044e-04 - val_semantic_3_loss: 0.0036
# Epoch 21/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0071 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0012 - semantic_2_loss: 6.0045e-04 - semantic_3_loss: 0.0029
# Epoch 00021: val_loss improved from 0.01276 to 0.01257, saving model to /deepcell_data/models/mousebrain3D_27x64_random_cropping_3daug_norotatev2_test.h5
# 392/392 [==============================] - 844s 2s/step - loss: 0.0071 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0012 - semantic_2_loss: 6.0165e-04 - semantic_3_loss: 0.0029 - val_loss: 0.0126 - val_semantic_0_loss: 0.0055 - val_semantic_1_loss: 0.0024 - val_semantic_2_loss: 8.3725e-04 - val_semantic_3_loss: 0.0038
# Epoch 22/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0071 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0012 - semantic_2_loss: 5.8806e-04 - semantic_3_loss: 0.0030
# Epoch 00022: val_loss improved from 0.01257 to 0.01255, saving model to /deepcell_data/models/mousebrain3D_27x64_random_cropping_3daug_norotatev2_test.h5
# 392/392 [==============================] - 847s 2s/step - loss: 0.0071 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0012 - semantic_2_loss: 5.8866e-04 - semantic_3_loss: 0.0030 - val_loss: 0.0125 - val_semantic_0_loss: 0.0055 - val_semantic_1_loss: 0.0023 - val_semantic_2_loss: 9.4018e-04 - val_semantic_3_loss: 0.0038
# Epoch 23/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0069 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0011 - semantic_2_loss: 5.9147e-04 - semantic_3_loss: 0.0030
# Epoch 00023: val_loss improved from 0.01255 to 0.01192, saving model to /deepcell_data/models/mousebrain3D_27x64_random_cropping_3daug_norotatev2_test.h5
# 392/392 [==============================] - 843s 2s/step - loss: 0.0069 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0011 - semantic_2_loss: 5.9145e-04 - semantic_3_loss: 0.0029 - val_loss: 0.0119 - val_semantic_0_loss: 0.0053 - val_semantic_1_loss: 0.0021 - val_semantic_2_loss: 7.9338e-04 - val_semantic_3_loss: 0.0037
# Epoch 24/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0072 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0012 - semantic_2_loss: 5.9538e-04 - semantic_3_loss: 0.0029
# Epoch 00024: val_loss did not improve from 0.01192
# 392/392 [==============================] - 834s 2s/step - loss: 0.0071 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0012 - semantic_2_loss: 5.9528e-04 - semantic_3_loss: 0.0029 - val_loss: 0.0129 - val_semantic_0_loss: 0.0059 - val_semantic_1_loss: 0.0025 - val_semantic_2_loss: 8.3089e-04 - val_semantic_3_loss: 0.0037
# Epoch 25/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0068 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0011 - semantic_2_loss: 5.9078e-04 - semantic_3_loss: 0.0029
# Epoch 00025: val_loss did not improve from 0.01192
# 392/392 [==============================] - 834s 2s/step - loss: 0.0068 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0011 - semantic_2_loss: 5.9057e-04 - semantic_3_loss: 0.0029 - val_loss: 0.0127 - val_semantic_0_loss: 0.0058 - val_semantic_1_loss: 0.0024 - val_semantic_2_loss: 8.6059e-04 - val_semantic_3_loss: 0.0037
# Epoch 26/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0070 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0011 - semantic_2_loss: 6.0531e-04 - semantic_3_loss: 0.0029
# Epoch 00026: val_loss did not improve from 0.01192
# 392/392 [==============================] - 834s 2s/step - loss: 0.0070 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0011 - semantic_2_loss: 6.0433e-04 - semantic_3_loss: 0.0029 - val_loss: 0.0135 - val_semantic_0_loss: 0.0064 - val_semantic_1_loss: 0.0025 - val_semantic_2_loss: 8.2378e-04 - val_semantic_3_loss: 0.0037
# Epoch 27/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0071 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0011 - semantic_2_loss: 6.0359e-04 - semantic_3_loss: 0.0029
# Epoch 00027: val_loss did not improve from 0.01192
# 392/392 [==============================] - 831s 2s/step - loss: 0.0071 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0011 - semantic_2_loss: 6.0286e-04 - semantic_3_loss: 0.0029 - val_loss: 0.0144 - val_semantic_0_loss: 0.0069 - val_semantic_1_loss: 0.0027 - val_semantic_2_loss: 8.9052e-04 - val_semantic_3_loss: 0.0040
# Epoch 28/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0070 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0012 - semantic_2_loss: 5.8329e-04 - semantic_3_loss: 0.0029
# Epoch 00028: val_loss did not improve from 0.01192
# 392/392 [==============================] - 835s 2s/step - loss: 0.0070 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0012 - semantic_2_loss: 5.8326e-04 - semantic_3_loss: 0.0029 - val_loss: 0.0127 - val_semantic_0_loss: 0.0058 - val_semantic_1_loss: 0.0024 - val_semantic_2_loss: 8.6470e-04 - val_semantic_3_loss: 0.0037
# Epoch 29/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0070 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0012 - semantic_2_loss: 5.7606e-04 - semantic_3_loss: 0.0029
# Epoch 00029: val_loss did not improve from 0.01192
# 392/392 [==============================] - 833s 2s/step - loss: 0.0070 - semantic_0_loss: 0.0024 - semantic_1_loss: 0.0012 - semantic_2_loss: 5.7682e-04 - semantic_3_loss: 0.0029 - val_loss: 0.0131 - val_semantic_0_loss: 0.0061 - val_semantic_1_loss: 0.0023 - val_semantic_2_loss: 9.3752e-04 - val_semantic_3_loss: 0.0038
# Epoch 30/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0068 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0011 - semantic_2_loss: 5.7606e-04 - semantic_3_loss: 0.0029
# Epoch 00030: val_loss improved from 0.01192 to 0.01174, saving model to /deepcell_data/models/mousebrain3D_27x64_random_cropping_3daug_norotatev2_test.h5
# 392/392 [==============================] - 846s 2s/step - loss: 0.0068 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0011 - semantic_2_loss: 5.7555e-04 - semantic_3_loss: 0.0029 - val_loss: 0.0117 - val_semantic_0_loss: 0.0052 - val_semantic_1_loss: 0.0022 - val_semantic_2_loss: 7.7887e-04 - val_semantic_3_loss: 0.0035
# Epoch 31/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0073 - semantic_0_loss: 0.0025 - semantic_1_loss: 0.0012 - semantic_2_loss: 6.6297e-04 - semantic_3_loss: 0.0029
# Epoch 00031: val_loss did not improve from 0.01174
# 392/392 [==============================] - 834s 2s/step - loss: 0.0073 - semantic_0_loss: 0.0025 - semantic_1_loss: 0.0012 - semantic_2_loss: 6.6281e-04 - semantic_3_loss: 0.0029 - val_loss: 0.0125 - val_semantic_0_loss: 0.0058 - val_semantic_1_loss: 0.0023 - val_semantic_2_loss: 8.2744e-04 - val_semantic_3_loss: 0.0036
# Epoch 32/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0067 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0011 - semantic_2_loss: 5.7437e-04 - semantic_3_loss: 0.0028
# Epoch 00032: val_loss did not improve from 0.01174
# 392/392 [==============================] - 831s 2s/step - loss: 0.0067 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0011 - semantic_2_loss: 5.7484e-04 - semantic_3_loss: 0.0028 - val_loss: 0.0132 - val_semantic_0_loss: 0.0059 - val_semantic_1_loss: 0.0025 - val_semantic_2_loss: 9.2584e-04 - val_semantic_3_loss: 0.0039
# Epoch 33/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0067 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0011 - semantic_2_loss: 5.8031e-04 - semantic_3_loss: 0.0028
# Epoch 00033: val_loss did not improve from 0.01174
# 392/392 [==============================] - 837s 2s/step - loss: 0.0067 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0011 - semantic_2_loss: 5.7977e-04 - semantic_3_loss: 0.0028 - val_loss: 0.0127 - val_semantic_0_loss: 0.0060 - val_semantic_1_loss: 0.0022 - val_semantic_2_loss: 8.5965e-04 - val_semantic_3_loss: 0.0037
# Epoch 34/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0069 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0011 - semantic_2_loss: 5.8157e-04 - semantic_3_loss: 0.0029
# Epoch 00034: val_loss did not improve from 0.01174
# 392/392 [==============================] - 834s 2s/step - loss: 0.0069 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0011 - semantic_2_loss: 5.8113e-04 - semantic_3_loss: 0.0029 - val_loss: 0.0128 - val_semantic_0_loss: 0.0055 - val_semantic_1_loss: 0.0023 - val_semantic_2_loss: 9.2864e-04 - val_semantic_3_loss: 0.0040
# Epoch 35/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0068 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0011 - semantic_2_loss: 5.6452e-04 - semantic_3_loss: 0.0028
# Epoch 00035: val_loss did not improve from 0.01174
# 392/392 [==============================] - 834s 2s/step - loss: 0.0068 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0011 - semantic_2_loss: 5.6467e-04 - semantic_3_loss: 0.0028 - val_loss: 0.0126 - val_semantic_0_loss: 0.0058 - val_semantic_1_loss: 0.0025 - val_semantic_2_loss: 7.7030e-04 - val_semantic_3_loss: 0.0036
# Epoch 36/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0068 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0011 - semantic_2_loss: 6.1329e-04 - semantic_3_loss: 0.0029
# Epoch 00036: val_loss improved from 0.01174 to 0.01158, saving model to /deepcell_data/models/mousebrain3D_27x64_random_cropping_3daug_norotatev2_test.h5
# 392/392 [==============================] - 847s 2s/step - loss: 0.0068 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0011 - semantic_2_loss: 6.1314e-04 - semantic_3_loss: 0.0029 - val_loss: 0.0116 - val_semantic_0_loss: 0.0049 - val_semantic_1_loss: 0.0023 - val_semantic_2_loss: 7.5913e-04 - val_semantic_3_loss: 0.0036
# Epoch 37/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0067 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0011 - semantic_2_loss: 5.7361e-04 - semantic_3_loss: 0.0028
# Epoch 00037: val_loss did not improve from 0.01158
# 392/392 [==============================] - 832s 2s/step - loss: 0.0067 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0011 - semantic_2_loss: 5.7398e-04 - semantic_3_loss: 0.0028 - val_loss: 0.0120 - val_semantic_0_loss: 0.0054 - val_semantic_1_loss: 0.0021 - val_semantic_2_loss: 7.7407e-04 - val_semantic_3_loss: 0.0037
# Epoch 38/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0067 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0010 - semantic_2_loss: 5.7037e-04 - semantic_3_loss: 0.0029
# Epoch 00038: val_loss did not improve from 0.01158
# 392/392 [==============================] - 831s 2s/step - loss: 0.0067 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0010 - semantic_2_loss: 5.7025e-04 - semantic_3_loss: 0.0029 - val_loss: 0.0120 - val_semantic_0_loss: 0.0051 - val_semantic_1_loss: 0.0023 - val_semantic_2_loss: 8.0719e-04 - val_semantic_3_loss: 0.0038
# Epoch 39/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0068 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0011 - semantic_2_loss: 5.6811e-04 - semantic_3_loss: 0.0029
# Epoch 00039: val_loss did not improve from 0.01158
# 392/392 [==============================] - 834s 2s/step - loss: 0.0068 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0011 - semantic_2_loss: 5.6771e-04 - semantic_3_loss: 0.0029 - val_loss: 0.0124 - val_semantic_0_loss: 0.0051 - val_semantic_1_loss: 0.0023 - val_semantic_2_loss: 9.0752e-04 - val_semantic_3_loss: 0.0041
# Epoch 40/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0066 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0010 - semantic_2_loss: 5.6451e-04 - semantic_3_loss: 0.0028
# Epoch 00040: val_loss did not improve from 0.01158
# 392/392 [==============================] - 835s 2s/step - loss: 0.0066 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0010 - semantic_2_loss: 5.6413e-04 - semantic_3_loss: 0.0028 - val_loss: 0.0127 - val_semantic_0_loss: 0.0057 - val_semantic_1_loss: 0.0024 - val_semantic_2_loss: 8.3408e-04 - val_semantic_3_loss: 0.0037
# Epoch 41/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0067 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0011 - semantic_2_loss: 5.7219e-04 - semantic_3_loss: 0.0028
# Epoch 00041: val_loss did not improve from 0.01158
# 392/392 [==============================] - 836s 2s/step - loss: 0.0067 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0011 - semantic_2_loss: 5.7155e-04 - semantic_3_loss: 0.0028 - val_loss: 0.0120 - val_semantic_0_loss: 0.0054 - val_semantic_1_loss: 0.0024 - val_semantic_2_loss: 7.7912e-04 - val_semantic_3_loss: 0.0034
# Epoch 42/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0067 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0010 - semantic_2_loss: 5.7619e-04 - semantic_3_loss: 0.0028
# Epoch 00042: val_loss did not improve from 0.01158
# 392/392 [==============================] - 834s 2s/step - loss: 0.0067 - semantic_0_loss: 0.0023 - semantic_1_loss: 0.0010 - semantic_2_loss: 5.7644e-04 - semantic_3_loss: 0.0028 - val_loss: 0.0135 - val_semantic_0_loss: 0.0061 - val_semantic_1_loss: 0.0026 - val_semantic_2_loss: 9.9328e-04 - val_semantic_3_loss: 0.0038
# Epoch 43/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0066 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0010 - semantic_2_loss: 5.5780e-04 - semantic_3_loss: 0.0028
# Epoch 00043: val_loss did not improve from 0.01158
# 392/392 [==============================] - 835s 2s/step - loss: 0.0066 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0010 - semantic_2_loss: 5.5793e-04 - semantic_3_loss: 0.0028 - val_loss: 0.0120 - val_semantic_0_loss: 0.0053 - val_semantic_1_loss: 0.0023 - val_semantic_2_loss: 8.1852e-04 - val_semantic_3_loss: 0.0035
# Epoch 44/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0065 - semantic_0_loss: 0.0022 - semantic_1_loss: 9.9883e-04 - semantic_2_loss: 5.4226e-04 - semantic_3_loss: 0.0028
# Epoch 00044: val_loss improved from 0.01158 to 0.01155, saving model to /deepcell_data/models/mousebrain3D_27x64_random_cropping_3daug_norotatev2_test.h5
# 392/392 [==============================] - 850s 2s/step - loss: 0.0065 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0010 - semantic_2_loss: 5.4280e-04 - semantic_3_loss: 0.0028 - val_loss: 0.0115 - val_semantic_0_loss: 0.0051 - val_semantic_1_loss: 0.0022 - val_semantic_2_loss: 7.5513e-04 - val_semantic_3_loss: 0.0035
# Epoch 45/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0065 - semantic_0_loss: 0.0022 - semantic_1_loss: 9.9531e-04 - semantic_2_loss: 5.4169e-04 - semantic_3_loss: 0.0028
# Epoch 00045: val_loss did not improve from 0.01155
# 392/392 [==============================] - 835s 2s/step - loss: 0.0065 - semantic_0_loss: 0.0022 - semantic_1_loss: 9.9750e-04 - semantic_2_loss: 5.4251e-04 - semantic_3_loss: 0.0028 - val_loss: 0.0121 - val_semantic_0_loss: 0.0052 - val_semantic_1_loss: 0.0023 - val_semantic_2_loss: 8.6493e-04 - val_semantic_3_loss: 0.0038
# Epoch 46/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0066 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0010 - semantic_2_loss: 5.4997e-04 - semantic_3_loss: 0.0028
# Epoch 00046: val_loss improved from 0.01155 to 0.01141, saving model to /deepcell_data/models/mousebrain3D_27x64_random_cropping_3daug_norotatev2_test.h5
# 392/392 [==============================] - 846s 2s/step - loss: 0.0066 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0010 - semantic_2_loss: 5.4965e-04 - semantic_3_loss: 0.0028 - val_loss: 0.0114 - val_semantic_0_loss: 0.0048 - val_semantic_1_loss: 0.0022 - val_semantic_2_loss: 8.0761e-04 - val_semantic_3_loss: 0.0036
# Epoch 47/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0066 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0010 - semantic_2_loss: 5.4460e-04 - semantic_3_loss: 0.0028
# Epoch 00047: val_loss did not improve from 0.01141
# 392/392 [==============================] - 835s 2s/step - loss: 0.0066 - semantic_0_loss: 0.0022 - semantic_1_loss: 0.0010 - semantic_2_loss: 5.4408e-04 - semantic_3_loss: 0.0028 - val_loss: 0.0121 - val_semantic_0_loss: 0.0052 - val_semantic_1_loss: 0.0023 - val_semantic_2_loss: 8.8710e-04 - val_semantic_3_loss: 0.0037
# Epoch 48/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0065 - semantic_0_loss: 0.0021 - semantic_1_loss: 9.8872e-04 - semantic_2_loss: 5.8457e-04 - semantic_3_loss: 0.0028
# Epoch 00048: val_loss improved from 0.01141 to 0.01106, saving model to /deepcell_data/models/mousebrain3D_27x64_random_cropping_3daug_norotatev2_test.h5
# 392/392 [==============================] - 848s 2s/step - loss: 0.0065 - semantic_0_loss: 0.0021 - semantic_1_loss: 9.8923e-04 - semantic_2_loss: 5.8465e-04 - semantic_3_loss: 0.0028 - val_loss: 0.0111 - val_semantic_0_loss: 0.0048 - val_semantic_1_loss: 0.0020 - val_semantic_2_loss: 7.1408e-04 - val_semantic_3_loss: 0.0035
# Epoch 49/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0065 - semantic_0_loss: 0.0022 - semantic_1_loss: 9.8778e-04 - semantic_2_loss: 5.7092e-04 - semantic_3_loss: 0.0028
# Epoch 00049: val_loss did not improve from 0.01106
# 392/392 [==============================] - 830s 2s/step - loss: 0.0065 - semantic_0_loss: 0.0022 - semantic_1_loss: 9.8762e-04 - semantic_2_loss: 5.7052e-04 - semantic_3_loss: 0.0028 - val_loss: 0.0122 - val_semantic_0_loss: 0.0054 - val_semantic_1_loss: 0.0023 - val_semantic_2_loss: 8.1423e-04 - val_semantic_3_loss: 0.0037
# Epoch 50/50
# 391/392 [============================>.] - ETA: 2s - loss: 0.0067 - semantic_0_loss: 0.0022 - semantic_1_loss: 9.8932e-04 - semantic_2_loss: 5.8102e-04 - semantic_3_loss: 0.0029
# Epoch 00050: val_loss did not improve from 0.01106
# 392/392 [==============================] - 831s 2s/step - loss: 0.0067 - semantic_0_loss: 0.0022 - semantic_1_loss: 9.8973e-04 - semantic_2_loss: 5.8085e-04 - semantic_3_loss: 0.0029 - val_loss: 0.0121 - val_semantic_0_loss: 0.0056 - val_semantic_1_loss: 0.0022 - val_semantic_2_loss: 8.3724e-04 - val_semantic_3_loss: 0.0035

# %% [markdown]
# ## Predict on test data
#
# Use the trained model to predict on new data. First, create a new prediction model without the foreground background semantic head. While this head is very useful during training, the output is unused during prediction. By using `model.load_weights(path, by_name=True)`, the semantic head can be removed.

# %%
# Instantiate prediction model
from deepcell.model_zoo.panopticnet import PanopticNet       
model = PanopticNet(
    backbone='resnet50',
    input_shape=input_shape,
    frames_per_batch=frames_per_batch,
    norm_method='std',
    num_semantic_heads=2,
    temporal_mode=temporal_mode,
    num_semantic_classes=[1, 1], # inner distance, outer distance
    location=True,  # should always be true
    include_top=True,
    z_axis_convolutions=z_axis_convolutions)
# Out:
# Using convolutions across the z-axis
# Using convolutions across the z-axis
# Using convolutions across the z-axis

# %%
# Load weights
model.load_weights(model_path, by_name=True)

# %%
def tile_predict_watershed(model,
                           X_test,
                           y_true,
                           input_shape,
                           stride_ratio=0.5,
                           min_distance=10,
                           detection_threshold=0.1,
                           distance_threshold=0.1,
                           small_objects_threshold=0,
                           force_spline=False,
                           spline_power=3,
                           batch_size=1):

    # Tile X_test into overlapping tiles
    X_tiles, tiles_info_X = tile_image_3D(X_test, model_input_shape=input_shape, stride_ratio=stride_ratio)
    
    # Predict on tiles 
    y_pred = model.predict(X_tiles, batch_size=batch_size)

    # Untile predictions
    y_pred = [untile_image_3D(o,
                              tiles_info_X,
                              model_input_shape=input_shape,
                              power=spline_power,
                              force=force_spline) for o in y_pred]
    
    # Run deep_watershed_3D on untiled predictions
    y_pred = deep_watershed_3D(
        y_pred,
        min_distance=min_distance,
        detection_threshold=detection_threshold,
        distance_threshold=distance_threshold,
        exclude_border=False,
        small_objects_threshold=small_objects_threshold)
        
    # Squeeze out channel dimension from y_true
    y_true = np.squeeze(y_true)
    
    # If batch dimension was squeezed out, add it back in
    if y_true.ndim < 4:
        y_true = np.expand_dims(y_true, 0)

    return y_true, y_pred

# %%
# Predict on tiles and composite for metrics analysis
input_shape = (frames_per_batch, frame_shape[0], frame_shape[1])
stride_ratio = 0.5  
min_distance = 10             # minimum allowable distance between two centroid coords **
detection_threshold = 0.05    # absolute threshold for minimum peak intensity (centroid detection) **
distance_threshold = 0.01     # outer_distance threshold for cell border **
batch_size = 1
spline_power = 2
force_spline = False

y_true, y_pred = tile_predict_watershed(model=model,
                                        X_test=X_test,
                                        y_true=y_test,
                                        input_shape=input_shape,
                                        stride_ratio=stride_ratio,
                                        min_distance=min_distance,
                                        detection_threshold=detection_threshold,
                                        distance_threshold=distance_threshold,
                                        small_objects_threshold=0,
                                        force_spline=force_spline,
                                        spline_power=spline_power)


print('Shape of y_pred is {} and shape of y_true is {}'.format(y_pred.shape, y_true.shape))
# Out:
# Shape of y_pred is (3, 47, 512, 512) and shape of y_true is (3, 47, 512, 512)

# %% [markdown]
# ## Run Metrics

# %%
from deepcell_toolbox.metrics import Metrics

print('Metrics: no small objects removed')
m = Metrics('DeepWatershed - Remove no pixels', seg=False, ndigits=3, cutoff1=0.5, cutoff2=0.7, is_3d=True, force_event_links=True)
m.calc_object_stats(y_true, y_pred)
# Out:
# Metrics: no small objects removed
#
# ____________Object-based statistics____________
#
# Number of true cells:		 260
# Number of predicted cells:	 251
#
# Correct detections:  234	Recall: 90.0%
# Incorrect detections: 17	Precision: 93.227%
#
# Gained detections: 17	Perc Error: 39.535%
# Missed detections: 26	Perc Error: 60.465%
# Merges: 0		Perc Error: 0.0%
# Splits: 0		Perc Error: 0.0%
# Catastrophes: 0		Perc Error: 0.0%
#
# Gained detections from splits: 0
# Missed detections from merges: 0
# True detections involved in catastrophes: 0
# Predicted detections involved in catastrophes: 0
#
# Average Pixel IOU (Jaccard Index): 0.776

# %%
from skimage.morphology import remove_small_objects

small_objects_threshold = 50

# remove small objects - there are some incorrect annotations of very small cells. Should consider removing before training.
for i in range(y_pred.shape[0]):
    y_pred[i] = remove_small_objects(y_pred[i].astype(int), min_size=small_objects_threshold)
    y_true[i] = remove_small_objects(y_true[i].astype(int), min_size=small_objects_threshold)

    y_pred[i], _, _ = relabel_sequential(y_pred[i])

# %%
from deepcell_toolbox.metrics import Metrics

m = Metrics('DeepWatershed - Remove <50', seg=False, ndigits=3, cutoff1=0.5, cutoff2=0.7, is_3d=True)
m.calc_object_stats(y_true, y_pred)
# Out:
# ____________Object-based statistics____________
#
# Number of true cells:		 252
# Number of predicted cells:	 245
#
# Correct detections:  234	Recall: 92.857%
# Incorrect detections: 11	Precision: 95.51%
#
# Gained detections: 11	Perc Error: 37.931%
# Missed detections: 18	Perc Error: 62.069%
# Merges: 0		Perc Error: 0.0%
# Splits: 0		Perc Error: 0.0%
# Catastrophes: 0		Perc Error: 0.0%
#
# Gained detections from splits: 0
# Missed detections from merges: 0
# True detections involved in catastrophes: 0
# Predicted detections involved in catastrophes: 0
#
# Average Pixel IOU (Jaccard Index): 0.776

# %% [markdown]
# ## Visualize Results

# %%
# Plot predicted/true centroids & volumes for one tile 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import random
from skimage.measure import regionprops
#from scipy import ndimage

fig = plt.figure(figsize=(15, 25))
index = 0
x_min = 0
x_max = 256 + x_min
y_min = 0
y_max = 256 + y_min
z_min = 0
z_max = 47 + z_min
masks = y_pred[index, z_min:z_max, x_min:x_max, y_min:y_max]
gt_mask = y_true[index, z_min:z_max, x_min:x_max, y_min:y_max]

# Predicted Cell volumes
ax = fig.add_subplot(211, projection='3d')
ax.set_xlim3d(x_min, x_max)
ax.set_ylim3d(x_min, y_max)
ax.set_zlim3d(z_min, z_max)
plot_masks = np.rollaxis(np.squeeze(masks), 0, 3)
colors = np.empty(plot_masks.shape, dtype='<U9')
color_dict = dict()

for label in np.unique(plot_masks):
    if label != 0:
        color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(8)])]
    else:
        color = None#'#7A88CCC0'
    color_dict[label] = color
    colors = np.where(plot_masks==label, color, colors)
ax.voxels(plot_masks, facecolors=colors)
ax.set_title('Predicted Cell Volumes')

# Ground truth Cell Volumes
ax = fig.add_subplot(212, projection='3d')
ax.set_xlim3d(0,x_max)
ax.set_ylim3d(0,y_max)
ax.set_zlim3d(z_min, z_max)
plot_masks = np.rollaxis(np.squeeze(gt_mask), 0, 3)
colors = np.empty(plot_masks.shape, dtype='<U9')
color_dict = dict()

for label in np.unique(plot_masks):
    if label != 0:
        color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(8)])]
    else:
        color = None#'#7A88CCC0'
    color_dict[label] = color
    colors = np.where(plot_masks==label, color, colors)

ax.voxels(plot_masks, facecolors=colors)
ax.set_title('Ground-truth Cell Volumes')
plt.show()
